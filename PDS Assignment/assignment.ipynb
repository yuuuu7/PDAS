# %% [markdown]
# Question 1

# %%
import numpy as np
import matplotlib as plt

#Initialize the contents of the different files into variables first
resale_1990_1999 ='./resale-flat-price-CSVs/resale-flat-prices-based-on-approval-date-1990-1999.csv'


resale_2000_2012 = './resale-flat-price-CSVs/resale-flat-prices-based-on-approval-date-2000-feb-2012.csv'
 
resale_mar2012_dec2014 = './resale-flat-price-CSVs/resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv'

resale_jan2015_dec2016 = './resale-flat-price-CSVs/resale-flat-prices-based-on-registration-date-from-jan-2015-to-dec-2016.csv'

resale_2017_onwards = './resale-flat-price-CSVs/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv'

#data set 1
data1 = np.genfromtxt(resale_1990_1999, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data1)

print(f"There are all together {rows} rows in the file {resale_1990_1999}")

data1_years_months = data1['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data1_1room = data1[np.where(data1['flat_type'] == keyword1)]
data1_2room = data1[np.where(data1['flat_type'] == keyword2)]
data1_3room = data1[np.where(data1['flat_type'] == keyword3)]
data1_4room = data1[np.where(data1['flat_type'] == keyword4)]
data1_5room = data1[np.where(data1['flat_type'] == keyword5)]
data1_6room = data1[np.where(data1['flat_type'] == keyword6)]


print(f'\nThere are a total number of {len(data1_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data1_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data1_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data1_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data1_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data1_6room)} {keyword6} resale flats')


#data set 2
data2 = np.genfromtxt(resale_2000_2012, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data2)

print(f"\nThere are all together {rows} rows in the file {resale_2000_2012}")

data2_years_months = data2['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data2_1room = data2[np.where(data2['flat_type'] == keyword1)]
data2_2room = data2[np.where(data2['flat_type'] == keyword2)]
data2_3room = data2[np.where(data2['flat_type'] == keyword3)]
data2_4room = data2[np.where(data2['flat_type'] == keyword4)]
data2_5room = data2[np.where(data2['flat_type'] == keyword5)]
data2_6room = data2[np.where(data2['flat_type'] == keyword6)]


print(f'\nThere are a total number of {len(data2_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data2_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data2_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data2_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data2_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data2_6room)} {keyword6} resale flats')

#data set 3
data3 = np.genfromtxt(resale_mar2012_dec2014, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data3)

print(f"\nThere are all together {rows} rows in the file {resale_mar2012_dec2014}")

data3_years_months = data3['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data3_1room = data3[np.where(data3['flat_type'] == keyword1)]
data3_2room = data3[np.where(data3['flat_type'] == keyword2)]
data3_3room = data3[np.where(data3['flat_type'] == keyword3)]
data3_4room = data3[np.where(data3['flat_type'] == keyword4)]
data3_5room = data3[np.where(data3['flat_type'] == keyword5)]
data3_6room = data3[np.where(data3['flat_type'] == keyword6)]


print(f'\nThere are a total number of {len(data3_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data3_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data3_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data3_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data3_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data3_6room)} {keyword6} resale flats')

#data set 4
data4 = np.genfromtxt(resale_jan2015_dec2016, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data4)

print(f"\nThere are all together {rows} rows in the file {resale_jan2015_dec2016}")

data4_years_months = data4['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data4_1room = data4[np.where(data4['flat_type'] == keyword1)]
data4_2room = data4[np.where(data4['flat_type'] == keyword2)]
data4_3room = data4[np.where(data4['flat_type'] == keyword3)]
data4_4room = data4[np.where(data4['flat_type'] == keyword4)]
data4_5room = data4[np.where(data4['flat_type'] == keyword5)]
data4_6room = data4[np.where(data4['flat_type'] == keyword6)]


print(f'\nThere are a total number of {len(data4_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data4_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data4_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data4_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data4_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data4_6room)} {keyword6} resale flats')
# Out:
# There are all together 287196 rows in the file ./resale-flat-price-CSVs/resale-flat-prices-based-on-approval-date-1990-1999.csv
#
# There are a total number of 827 1 ROOM resale flats
# There are a total number of 4140 2 ROOM resale flats
# There are a total number of 113102 3 ROOM resale flats
# There are a total number of 98521 4 ROOM resale flats
# There are a total number of 48206 5 ROOM resale flats
# There are a total number of 22121 EXECUTIVE resale flats
#
# There are all together 369651 rows in the file ./resale-flat-price-CSVs/resale-flat-prices-based-on-approval-date-2000-feb-2012.csv
#
# There are a total number of 355 1 ROOM resale flats
# There are a total number of 3554 2 ROOM resale flats
# There are a total number of 114661 3 ROOM resale flats
# There are a total number of 142171 4 ROOM resale flats
# There are a total number of 81675 5 ROOM resale flats
# There are a total number of 27075 EXECUTIVE resale flats
#
# ...

# %%
import numpy as np
import matplotlib as plt

#Initialize the contents of the different files into variables first
resale_1990_1999 ='./resale-flat-price-CSVs/resale-flat-prices-based-on-approval-date-1990-1999.csv'


resale_2000_2012 = './resale-flat-price-CSVs/resale-flat-prices-based-on-approval-date-2000-feb-2012.csv'
 
resale_mar2012_dec2014 = './resale-flat-price-CSVs/resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv'

resale_jan2015_dec2016 = './resale-flat-price-CSVs/resale-flat-prices-based-on-registration-date-from-jan-2015-to-dec-2016.csv'

resale_2017_onwards = './resale-flat-price-CSVs/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv'

#data set 1
data1 = np.genfromtxt(resale_1990_1999, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data1)

print(f"There are all together {rows} rows in the file {resale_1990_1999}")

data1_years_months = data1['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = '6 ROOM'
keyword7 = 'EXECUTIVE'

data1_1room = data1[data1['flat_type'] == keyword1]
data1_2room = data1[data1['flat_type'] == keyword2]
data1_3room = data1[data1['flat_type'] == keyword3]
data1_4room = data1[data1['flat_type'] == keyword4]
data1_5room = data1[data1['flat_type'] == keyword5]
data1_6room = data1[data1['flat_type'] == keyword6]
data1_7room = data1[data1['flat_type'] == keyword7]

print(f'\nThere are a total number of {len(data1_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data1_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data1_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data1_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data1_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data1_6room)} {keyword6} resale flats')
print(f'There are a total number of {len(data1_7room)} {keyword7} resale flats')

#data set 2
data2 = np.genfromtxt(resale_2000_2012, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data2)

print(f"\nThere are all together {rows} rows in the file {resale_2000_2012}")

data2_years_months = data2['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data2_1room = data2[data2['flat_type'] == keyword1]
data2_2room = data2[data2['flat_type'] == keyword2]
data2_3room = data2[data2['flat_type'] == keyword3]
data2_4room = data2[data2['flat_type'] == keyword4]
data2_5room = data2[data2['flat_type'] == keyword5]
data2_6room = data2[data2['flat_type'] == keyword6]


print(f'\nThere are a total number of {len(data2_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data2_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data2_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data2_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data2_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data2_6room)} {keyword6} resale flats')

#data set 3
data3 = np.genfromtxt(resale_mar2012_dec2014, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data3)

print(f"\nThere are all together {rows} rows in the file {resale_mar2012_dec2014}")

data3_years_months = data3['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data3_1room = data3[data3['flat_type'] == keyword1]
data3_2room = data3[data3['flat_type'] == keyword2]
data3_3room = data3[data3['flat_type'] == keyword3]
data3_4room = data3[data3['flat_type'] == keyword4]
data3_5room = data3[data3['flat_type'] == keyword5]
data3_6room = data3[data3['flat_type'] == keyword6]


print(f'\nThere are a total number of {len(data3_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data3_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data3_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data3_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data3_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data3_6room)} {keyword6} resale flats')

#data set 4
data4 = np.genfromtxt(resale_jan2015_dec2016, encoding=None, dtype=None, delimiter=',', names=True)

rows = len(data4)

print(f"\nThere are all together {rows} rows in the file {resale_jan2015_dec2016}")

data4_years_months = data4['month']

keyword1 = '1 ROOM'
keyword2 = '2 ROOM'
keyword3 = '3 ROOM'
keyword4 = '4 ROOM'
keyword5 = '5 ROOM'
keyword6 = 'EXECUTIVE'

data4_1room = data4[data4['flat_type'] == keyword1]
data4_2room = data4[data4['flat_type'] == keyword2]
data4_3room = data4[data4['flat_type'] == keyword3]
data4_4room = data4[data4['flat_type'] == keyword4]
data4_5room = data4[data4['flat_type'] == keyword5]
data4_6room = data4[data4['flat_type'] == keyword6]


print(f'\nThere are a total number of {len(data4_1room)} {keyword1} resale flats')
print(f'There are a total number of {len(data4_2room)} {keyword2} resale flats')
print(f'There are a total number of {len(data4_3room)} {keyword3} resale flats')
print(f'There are a total number of {len(data4_4room)} {keyword4} resale flats')
print(f'There are a total number of {len(data4_5room)} {keyword5} resale flats')
print(f'There are a total number of {len(data4_6room)} {keyword6} resale flats')
